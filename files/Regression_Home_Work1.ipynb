# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x1=np.append((np.random.random(500)*-3),(np.random.random(500)*3))
x2=np.append((np.random.random(500)*-3),(np.random.random(500)*3))

# %%
noise=np.random.randn(1000)
y=2*x1+3*x2+noise*0.5

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
dataset=pd.DataFrame({'x1':x1,'x2':x2,'y':y},columns=['x1','x2','y'])

lr.fit(dataset[['x1','x2']],dataset[['y']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X=np.linspace(1000,-3,3)

# %%
plt.scatter(x1,y)
plt.scatter(x2,y)

# %%
bias=lr.intercept_
cof=lr.coef_
#dummyx1=np.linspace(-3,3,1000)
#dummyx2=np.linspace(-3,3,1000)
#y_out=((cof[0])*dummyx1)+((cof[1])*dummyx2)+bias
#plt.plot(x1,y_out)
#plt.plot(x2,y_out)
# Out:
#   File "<ipython-input-50-bae473d219ff>", line 10
#     cof[[0:0]]
#           ^
# SyntaxError: invalid syntax
